# %% [markdown]
# # Импорт библиотек

# %%
import pandas as pd
import numpy as np
import warnings
import os
warnings.filterwarnings("ignore")

# %%
dir = os.path.abspath(os.curdir)
dir
# Out:
# 'c:\\Users\\Anton\\Desktop\\python\\task'

# %% [markdown]
# # Подготовка данных

# %%
# reading json into DF
orders = pd.read_json('trial_task.json', encoding="utf-8")

def unpack(el: list) -> "pd.DataFrame":
    """ Unpacking "products" and joining them for order_id

    Args:
        el (list): List of json elements

    Returns:
        pd.DataFrame: DataFrame with products list as columns
    """
    order_id, warehouse_name, highway_cost, produts = el
    left_df = pd.DataFrame([(order_id, warehouse_name, highway_cost)],
                            columns=['order_id', 'warehouse_name', 'highway_cost'])

    return left_df.join(pd.DataFrame.from_dict(produts), how='cross')

res_df = pd.DataFrame()

# joining all order_ids together in one DF
for el in orders.values:
    res_df = pd.concat([res_df, unpack(el)])

res_df.reset_index(inplace=True, drop=True)

# %%
res_df
# Out:
#      order_id       warehouse_name  highway_cost                   product  \
# 0       11973               Мордор           -70     ломтик июльского неба
# 1       11973               Мордор           -70           билет в Израиль
# 2       11973               Мордор           -70          статуэтка Ленина
# 3       62239  хутор близ Диканьки           -15           билет в Израиль
# 4       85794           отель Лето           -50         зеленая пластинка
# ..        ...                  ...           ...                       ...
# 192     79293           отель Лето           -75  автограф Стаса Барецкого
# 193     79293           отель Лето           -75     ломтик июльского неба
# 194      2930               Мордор           -30                   плюмбус
# 195      2930               Мордор           -30                   плюмбус
# 196       124  хутор близ Диканьки           -45                   плюмбус
#
#      price  quantity
# 0      450         1
# 1     1000         3
# 2      200         3
# 3     1000         1
# 4       10         2
# ..     ...       ...
# 192    600         1
# 193    450         1
# 194    250         2
# 195    250         1
# 196    250         3
#
# [197 rows x 6 columns]

# %% [markdown]
# # Задача 1

# %%
def get_warehouse_cost(df: 'pd.DataFrame') -> 'pd.DataFrame':
    warehouse_order = df[df['order_id'] == df['order_id'].unique()[0]]
    return warehouse_order['highway_cost'].unique()[0]/warehouse_order['quantity'].sum()

warehouse_cost = pd.DataFrame(res_df.groupby(['warehouse_name']).apply(get_warehouse_cost), columns=['warehouse_cost']).reset_index()
warehouse_cost
# Out:
#         warehouse_name  warehouse_cost
# 0               Мордор           -10.0
# 1           гиперборея           -20.0
# 2     остров невезения            -5.0
# 3           отель Лето           -25.0
# 4  хутор близ Диканьки           -15.0

# %% [markdown]
# # Задача 2

# %%
res_df_cost = res_df.set_index('warehouse_name').join(warehouse_cost.set_index('warehouse_name'))
res_df_cost['expense'] = res_df_cost['warehouse_cost'] * res_df_cost['quantity']
res_df_cost.reset_index(inplace=True)
res_df_cost
# Out:
#           warehouse_name  order_id  highway_cost                 product  \
# 0                 Мордор     11973           -70   ломтик июльского неба
# 1                 Мордор     11973           -70         билет в Израиль
# 2                 Мордор     11973           -70        статуэтка Ленина
# 3                 Мордор     33684           -30         билет в Израиль
# 4                 Мордор     33684           -30       зеленая пластинка
# ..                   ...       ...           ...                     ...
# 192  хутор близ Диканьки     15237           -60                 плюмбус
# 193  хутор близ Диканьки     15237           -60       зеленая пластинка
# 194  хутор близ Диканьки     28106           -30  подписка на suppi-блог
# 195  хутор близ Диканьки     28106           -30        статуэтка Ленина
# 196  хутор близ Диканьки       124           -45                 плюмбус
#
#      price  quantity  warehouse_cost  expense
# 0      450         1           -10.0    -10.0
# 1     1000         3           -10.0    -30.0
# 2      200         3           -10.0    -30.0
# 3     1000         2           -10.0    -20.0
# 4       10         1           -10.0    -10.0
# ..     ...       ...             ...      ...
# 192    250         1           -15.0    -15.0
# 193     10         2           -15.0    -30.0
# 194    150         1           -15.0    -15.0
# 195    200         1           -15.0    -15.0
# 196    250         3           -15.0    -45.0
#
# [197 rows x 8 columns]

# %%
product_sum = res_df_cost.groupby(['product']).sum().reset_index()
product_sum['profit'] = product_sum['price'] - product_sum['expense']
product_sum[['product','quantity', 'price', 'expense', 'profit']]
# Out:
#                     product  quantity  price  expense   profit
# 0  автограф Стаса Барецкого        48  16200   -820.0  17020.0
# 1           билет в Израиль        58  29000  -1050.0  30050.0
# 2         зеленая пластинка        61    310   -920.0   1230.0
# 3     ломтик июльского неба        42   9450   -670.0  10120.0
# 4                   плюмбус        65   8250   -940.0   9190.0
# 5    подписка на suppi-блог        33   2850   -545.0   3395.0
# 6          статуэтка Ленина        68   7400   -935.0   8335.0

# %% [markdown]
# # Задача 3

# %%
res_df_cost['order_price'] = res_df_cost['price']*res_df_cost['quantity']
order_profit_df = res_df_cost.groupby(['order_id', 'highway_cost']).sum().reset_index()
order_profit_df['order_profit'] = order_profit_df['order_price'] + order_profit_df['highway_cost']

print("Средняя прибыль заказов", order_profit_df['order_profit'].mean())
order_profit_df[['order_id', 'order_profit']]
# Out:
# Средняя прибыль заказов 1352.3
#     order_id  order_profit
# 0        124           705
# 1       1391           490
# 2       2091          1300
# 3       2108           200
# 4       2558           355
# ..       ...           ...
# 95     98100          1590
# 96     98423          1170
# 97     99220          1075
# 98     99246          1755
# 99     99324          1590
#
# [100 rows x 2 columns]

# %% [markdown]
# # Задача 4

# %%
# group by  warehouse_name and product
warehouse_profit = res_df_cost.groupby(
    ['warehouse_name', 'product']).sum().reset_index()
# calculating product profit inside warehouse
warehouse_profit['profit'] = warehouse_profit['order_price'] + warehouse_profit['expense']

# DF with warehouse_profit, calculating warehouse profit inside warehouse
warehouse_profit = warehouse_profit.set_index('warehouse_name').join(
    warehouse_profit.groupby(['warehouse_name']).sum().rename(
        columns={'profit':'profit_warehouse'})['profit_warehouse']).reset_index()

# calculating percent_profit_product_of_warehouse
warehouse_profit['percent_profit_product_of_warehouse'] = (
    warehouse_profit['profit']/warehouse_profit['profit_warehouse']) * 100
# resulting DF 
warehouse_profit = warehouse_profit[['warehouse_name',
                                      'product',
                                        'quantity',
                                          'profit',
                                            'percent_profit_product_of_warehouse']]
warehouse_profit
# Out:
#          warehouse_name                   product  quantity   profit  \
# 0                Мордор  автограф Стаса Барецкого         4   2360.0
# 1                Мордор           билет в Израиль         9   8910.0
# 2                Мордор         зеленая пластинка        11      0.0
# 3                Мордор     ломтик июльского неба         3   1320.0
# 4                Мордор                   плюмбус         6   1440.0
# 5                Мордор    подписка на suppi-блог         8   1120.0
# 6                Мордор          статуэтка Ленина        10   1900.0
# 7            гиперборея  автограф Стаса Барецкого        12   6960.0
# 8            гиперборея           билет в Израиль        21  20580.0
# 9            гиперборея         зеленая пластинка        10   -100.0
# 10           гиперборея     ломтик июльского неба        13   5590.0
# 11           гиперборея                   плюмбус         9   2070.0
# 12           гиперборея    подписка на suppi-блог        12   1560.0
# 13           гиперборея          статуэтка Ленина         9   1620.0
# 14     остров невезения  автограф Стаса Барецкого         2   1190.0
# 15     остров невезения           билет в Израиль         3   2985.0
# 16     остров невезения         зеленая пластинка         9     45.0
# 17     остров невезения     ломтик июльского неба        10   4450.0
# 18     остров невезения                   плюмбус        14   3430.0
# 19     остров невезения          статуэтка Ленина        18   3510.0
# 20           отель Лето  автограф Стаса Барецкого         8   4600.0
# 21           отель Лето           билет в Израиль        15  14625.0
# 22           отель Лето         зеленая пластинка        10   -150.0
# 23           отель Лето     ломтик июльского неба         9   3825.0
# 24           отель Лето                   плюмбус         9   2025.0
# 25           отель Лето    подписка на suppi-блог         3    375.0
# 26           отель Лето          статуэтка Ленина        10   1750.0
# 27  хутор близ Диканьки  автограф Стаса Барецкого        22  12870.0
# 28  хутор близ Диканьки           билет в Израиль        10   9850.0
# 29  хутор близ Диканьки         зеленая пластинка        21   -105.0
# 30  хутор близ Диканьки     ломтик июльского неба         7   3045.0
# 31  хутор близ Диканьки                   плюмбус        27   6345.0
# 32  хутор близ Диканьки    подписка на suppi-блог        10   1350.0
# 33  хутор близ Диканьки          статуэтка Ленина        21   3885.0
#
#     percent_profit_product_of_warehouse
# 0                             13.841642
# 1                             52.258065
# 2                              0.000000
# 3                              7.741935
# 4                              8.445748
# 5                              6.568915
# 6                             11.143695
# 7                             18.181818
# 8                             53.761755
# 9                             -0.261233
# 10                            14.602926
# 11                             5.407524
# 12                             4.075235
# 13                             4.231975
# 14                             7.623318
# 15                            19.122357
# 16                             0.288277
# 17                            28.507367
# 18                            21.973094
# 19                            22.485586
# 20                            17.005545
# 21                            54.066543
# 22                            -0.554529
# 23                            14.140481
# 24                             7.486137
# 25                             1.386322
# 26                             6.469501
# 27                            34.559613
# 28                            26.450054
# 29                            -0.281955
# 30                             8.176692
# 31                            17.038131
# 32                             3.625134
# 33                            10.432331

# %% [markdown]
# # Задача 5

# %%
warehouse_profit = warehouse_profit.sort_values(
    by=['warehouse_name',
        'percent_profit_product_of_warehouse'],
          ascending=False).reset_index(drop=True)
x = 0
accumulated = []
warehouse_profit['accumulated_percent_profit_product_of_warehouse'] = warehouse_profit['percent_profit_product_of_warehouse']
# creating list of accumulating percents
for el in  warehouse_profit['accumulated_percent_profit_product_of_warehouse'].values:
  x += el
  accumulated.append(x)
  # going arround python round errors
  if (x % 100 < 0.001) | (x % 100 > 99.999) :
    x = 0
warehouse_profit['accumulated_percent_profit_product_of_warehouse'] = accumulated 
warehouse_profit
# Out:
#          warehouse_name                   product  quantity   profit  \
# 0   хутор близ Диканьки  автограф Стаса Барецкого        22  12870.0
# 1   хутор близ Диканьки           билет в Израиль        10   9850.0
# 2   хутор близ Диканьки                   плюмбус        27   6345.0
# 3   хутор близ Диканьки          статуэтка Ленина        21   3885.0
# 4   хутор близ Диканьки     ломтик июльского неба         7   3045.0
# 5   хутор близ Диканьки    подписка на suppi-блог        10   1350.0
# 6   хутор близ Диканьки         зеленая пластинка        21   -105.0
# 7            отель Лето           билет в Израиль        15  14625.0
# 8            отель Лето  автограф Стаса Барецкого         8   4600.0
# 9            отель Лето     ломтик июльского неба         9   3825.0
# 10           отель Лето                   плюмбус         9   2025.0
# 11           отель Лето          статуэтка Ленина        10   1750.0
# 12           отель Лето    подписка на suppi-блог         3    375.0
# 13           отель Лето         зеленая пластинка        10   -150.0
# 14     остров невезения     ломтик июльского неба        10   4450.0
# 15     остров невезения          статуэтка Ленина        18   3510.0
# 16     остров невезения                   плюмбус        14   3430.0
# 17     остров невезения           билет в Израиль         3   2985.0
# 18     остров невезения  автограф Стаса Барецкого         2   1190.0
# 19     остров невезения         зеленая пластинка         9     45.0
# 20           гиперборея           билет в Израиль        21  20580.0
# 21           гиперборея  автограф Стаса Барецкого        12   6960.0
# 22           гиперборея     ломтик июльского неба        13   5590.0
# 23           гиперборея                   плюмбус         9   2070.0
# 24           гиперборея          статуэтка Ленина         9   1620.0
# 25           гиперборея    подписка на suppi-блог        12   1560.0
# 26           гиперборея         зеленая пластинка        10   -100.0
# 27               Мордор           билет в Израиль         9   8910.0
# 28               Мордор  автограф Стаса Барецкого         4   2360.0
# 29               Мордор          статуэтка Ленина        10   1900.0
# 30               Мордор                   плюмбус         6   1440.0
# 31               Мордор     ломтик июльского неба         3   1320.0
# 32               Мордор    подписка на suppi-блог         8   1120.0
# 33               Мордор         зеленая пластинка        11      0.0
#
#     percent_profit_product_of_warehouse  \
# 0                             34.559613
# 1                             26.450054
# 2                             17.038131
# 3                             10.432331
# 4                              8.176692
# 5                              3.625134
# 6                             -0.281955
# 7                             54.066543
# 8                             17.005545
# 9                             14.140481
# 10                             7.486137
# 11                             6.469501
# 12                             1.386322
# 13                            -0.554529
# 14                            28.507367
# 15                            22.485586
# 16                            21.973094
# 17                            19.122357
# 18                             7.623318
# 19                             0.288277
# 20                            53.761755
# 21                            18.181818
# 22                            14.602926
# 23                             5.407524
# 24                             4.231975
# 25                             4.075235
# 26                            -0.261233
# 27                            52.258065
# 28                            13.841642
# 29                            11.143695
# 30                             8.445748
# 31                             7.741935
# 32                             6.568915
# 33                             0.000000
#
#     accumulated_percent_profit_product_of_warehouse
# 0                                         34.559613
# 1                                         61.009667
# 2                                         78.047798
# 3                                         88.480129
# 4                                         96.656821
# 5                                        100.281955
# 6                                        100.000000
# 7                                         54.066543
# 8                                         71.072089
# 9                                         85.212569
# 10                                        92.698706
# 11                                        99.168207
# 12                                       100.554529
# 13                                       100.000000
# 14                                        28.507367
# 15                                        50.992953
# 16                                        72.966047
# 17                                        92.088405
# 18                                        99.711723
# 19                                       100.000000
# 20                                        53.761755
# 21                                        71.943574
# 22                                        86.546499
# 23                                        91.954023
# 24                                        96.185998
# 25                                       100.261233
# 26                                       100.000000
# 27                                        52.258065
# 28                                        66.099707
# 29                                        77.243402
# 30                                        85.689150
# 31                                        93.431085
# 32                                       100.000000
# 33                                         0.000000

# %% [markdown]
# # Задача 6

# %%
# 
warehouse_profit['category'] = 'B'
warehouse_profit.loc[warehouse_profit[warehouse_profit.accumulated_percent_profit_product_of_warehouse <= 70].index, 'category'] = 'A'
warehouse_profit.loc[warehouse_profit[warehouse_profit.accumulated_percent_profit_product_of_warehouse > 90].index, 'category'] = 'C'
warehouse_profit
# Out:
#          warehouse_name                   product  quantity   profit  \
# 0   хутор близ Диканьки  автограф Стаса Барецкого        22  12870.0
# 1   хутор близ Диканьки           билет в Израиль        10   9850.0
# 2   хутор близ Диканьки                   плюмбус        27   6345.0
# 3   хутор близ Диканьки          статуэтка Ленина        21   3885.0
# 4   хутор близ Диканьки     ломтик июльского неба         7   3045.0
# 5   хутор близ Диканьки    подписка на suppi-блог        10   1350.0
# 6   хутор близ Диканьки         зеленая пластинка        21   -105.0
# 7            отель Лето           билет в Израиль        15  14625.0
# 8            отель Лето  автограф Стаса Барецкого         8   4600.0
# 9            отель Лето     ломтик июльского неба         9   3825.0
# 10           отель Лето                   плюмбус         9   2025.0
# 11           отель Лето          статуэтка Ленина        10   1750.0
# 12           отель Лето    подписка на suppi-блог         3    375.0
# 13           отель Лето         зеленая пластинка        10   -150.0
# 14     остров невезения     ломтик июльского неба        10   4450.0
# 15     остров невезения          статуэтка Ленина        18   3510.0
# 16     остров невезения                   плюмбус        14   3430.0
# 17     остров невезения           билет в Израиль         3   2985.0
# 18     остров невезения  автограф Стаса Барецкого         2   1190.0
# 19     остров невезения         зеленая пластинка         9     45.0
# 20           гиперборея           билет в Израиль        21  20580.0
# 21           гиперборея  автограф Стаса Барецкого        12   6960.0
# 22           гиперборея     ломтик июльского неба        13   5590.0
# 23           гиперборея                   плюмбус         9   2070.0
# 24           гиперборея          статуэтка Ленина         9   1620.0
# 25           гиперборея    подписка на suppi-блог        12   1560.0
# 26           гиперборея         зеленая пластинка        10   -100.0
# 27               Мордор           билет в Израиль         9   8910.0
# 28               Мордор  автограф Стаса Барецкого         4   2360.0
# 29               Мордор          статуэтка Ленина        10   1900.0
# 30               Мордор                   плюмбус         6   1440.0
# 31               Мордор     ломтик июльского неба         3   1320.0
# 32               Мордор    подписка на suppi-блог         8   1120.0
# 33               Мордор         зеленая пластинка        11      0.0
#
#     percent_profit_product_of_warehouse  \
# 0                             34.559613
# 1                             26.450054
# 2                             17.038131
# 3                             10.432331
# 4                              8.176692
# 5                              3.625134
# 6                             -0.281955
# 7                             54.066543
# 8                             17.005545
# 9                             14.140481
# 10                             7.486137
# 11                             6.469501
# 12                             1.386322
# 13                            -0.554529
# 14                            28.507367
# 15                            22.485586
# 16                            21.973094
# 17                            19.122357
# 18                             7.623318
# 19                             0.288277
# 20                            53.761755
# 21                            18.181818
# 22                            14.602926
# 23                             5.407524
# 24                             4.231975
# 25                             4.075235
# 26                            -0.261233
# 27                            52.258065
# 28                            13.841642
# 29                            11.143695
# 30                             8.445748
# 31                             7.741935
# 32                             6.568915
# 33                             0.000000
#
#     accumulated_percent_profit_product_of_warehouse category
# 0                                         34.559613        A
# 1                                         61.009667        A
# 2                                         78.047798        B
# 3                                         88.480129        B
# 4                                         96.656821        C
# 5                                        100.281955        C
# 6                                        100.000000        C
# 7                                         54.066543        A
# 8                                         71.072089        B
# 9                                         85.212569        B
# 10                                        92.698706        C
# 11                                        99.168207        C
# 12                                       100.554529        C
# 13                                       100.000000        C
# 14                                        28.507367        A
# 15                                        50.992953        A
# 16                                        72.966047        B
# 17                                        92.088405        C
# 18                                        99.711723        C
# 19                                       100.000000        C
# 20                                        53.761755        A
# 21                                        71.943574        B
# 22                                        86.546499        B
# 23                                        91.954023        C
# 24                                        96.185998        C
# 25                                       100.261233        C
# 26                                       100.000000        C
# 27                                        52.258065        A
# 28                                        66.099707        A
# 29                                        77.243402        B
# 30                                        85.689150        B
# 31                                        93.431085        C
# 32                                       100.000000        C
# 33                                         0.000000        A
